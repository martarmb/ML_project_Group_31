# %% [markdown]
# ## Import

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# setting seaborn style
sns.set()

from sklearn.model_selection import train_test_split

pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_colwidth', None) #Show all columns

# %% [markdown]
# ### Import Datasets

# %%
train_data = pd.read_csv("project_data/train_data.csv", low_memory=False)
test_data = pd.read_csv("project_data/test_data.csv")

# %%
print(train_data.head())
print(test_data.head())
# Out:
#   Accident Date  Age at Injury Alternative Dispute Resolution Assembly Date  \
# 0    2019-12-30           31.0                              N    2020-01-01
# 1    2019-08-30           46.0                              N    2020-01-01
# 2    2019-12-06           40.0                              N    2020-01-01
# 3           NaN            NaN                            NaN    2020-01-01
# 4    2019-12-30           61.0                              N    2020-01-01
#
#   Attorney/Representative  Average Weekly Wage  Birth Year    C-2 Date  \
# 0                       N                 0.00      1988.0  2019-12-31
# 1                       Y              1745.93      1973.0  2020-01-01
# 2                       N              1434.80      1979.0  2020-01-01
# 3                     NaN                  NaN         NaN         NaN
# 4                       N                  NaN      1958.0  2019-12-31
#
#      C-3 Date                  Carrier Name  ... WCIO Cause of Injury Code  \
# 0         NaN    NEW HAMPSHIRE INSURANCE CO  ...                      27.0
# 1  2020-01-14  ZURICH AMERICAN INSURANCE CO  ...                      97.0
# 2         NaN     INDEMNITY INSURANCE CO OF  ...                      79.0
# 3         NaN                           NaN  ...                       NaN
# 4         NaN          STATE INSURANCE FUND  ...                      16.0
#
#    WCIO Cause of Injury Description WCIO Nature of Injury Code  \
# 0      FROM LIQUID OR GREASE SPILLS                       10.0
# 1                 REPETITIVE MOTION                       49.0
# 2    OBJECT BEING LIFTED OR HANDLED                        7.0
# 3                               NaN                        NaN
# 4   HAND TOOL, UTENSIL; NOT POWERED                       43.0
#
#   WCIO Nature of Injury Description WCIO Part Of Body Code  \
# 0                         CONTUSION                   62.0
# 1                    SPRAIN OR TEAR                   38.0
# 2                        CONCUSSION                   10.0
# 3                               NaN                    NaN
# 4                          PUNCTURE                   36.0
#
#   WCIO Part Of Body Description Zip Code Agreement Reached      WCB Decision  \
# 0                      BUTTOCKS    13662               0.0  Not Work Related
# 1                   SHOULDER(S)    14569               1.0  Not Work Related
# 2          MULTIPLE HEAD INJURY    12589               0.0  Not Work Related
# 3                           NaN      NaN               NaN               NaN
# 4                     FINGER(S)    12603               0.0  Not Work Related
#
#    Number of Dependents
# 0                   1.0
# 1                   4.0
# 2                   6.0
# 3                   NaN
# 4                   1.0
#
# [5 rows x 33 columns]
#   Accident Date  Age at Injury Alternative Dispute Resolution Assembly Date  \
# 0    2022-12-24             19                              N    2023-01-02
# 1    2022-11-20             19                              N    2023-01-02
# 2    2022-12-26             59                              N    2023-01-02
# 3    2022-12-28             55                              N    2023-01-02
# 4    2022-12-20             25                              N    2023-01-02
#
#   Attorney/Representative  Average Weekly Wage  Birth Year    C-2 Date  \
# 0                       N                  NaN      2003.0  2023-01-02
# 1                       N                  NaN      2003.0  2023-01-02
# 2                       N                  0.0      1963.0  2022-12-31
# 3                       N                  0.0         0.0  2023-01-02
# 4                       N                  0.0      1997.0  2022-12-31
#
#   C-3 Date                 Carrier Name  ... Medical Fee Region  \
# 0      NaN    INDEMNITY INSURANCE CO OF  ...                 IV
# 1      NaN      A I U INSURANCE COMPANY  ...                 IV
# 2      NaN    AMGUARD INSURANCE COMPANY  ...                III
# 3      NaN  INDEMNITY INS. OF N AMERICA  ...                 IV
# 4      NaN   NEW HAMPSHIRE INSURANCE CO  ...                 IV
#
#    OIICS Nature of Injury Description WCIO Cause of Injury Code  \
# 0                                 NaN                      31.0
# 1                                 NaN                      75.0
# 2                                 NaN                      68.0
# 3                                 NaN                      25.0
# 4                                 NaN                      79.0
#
#    WCIO Cause of Injury Description WCIO Nature of Injury Code  \
# 0           FALL, SLIP OR TRIP, NOC                       10.0
# 1          FALLING OR FLYING OBJECT                       10.0
# 2                 STATIONARY OBJECT                       49.0
# 3  FROM DIFFERENT LEVEL (ELEVATION)                       10.0
# 4    OBJECT BEING LIFTED OR HANDLED                       40.0
#
#   WCIO Nature of Injury Description WCIO Part Of Body Code  \
# 0                         CONTUSION                   54.0
# 1                         CONTUSION                   10.0
# 2                    SPRAIN OR TEAR                   62.0
# 3                         CONTUSION                   53.0
# 4                        LACERATION                   37.0
#
#    WCIO Part Of Body Description  Zip Code Number of Dependents
# 0                      LOWER LEG     10466                    1
# 1           MULTIPLE HEAD INJURY     11691                    1
# 2                       BUTTOCKS     10604                    0
# 3                           KNEE     11411                    6
# 4                          THUMB     11212                    5
#
# [5 rows x 30 columns]

# %%
print(train_data.tail())
print(test_data.tail())
# Out:
#        Accident Date  Age at Injury Alternative Dispute Resolution  \
# 593466           NaN            NaN                            NaN
# 593467    2022-12-13           72.0                              N
# 593468           NaN            NaN                            NaN
# 593469           NaN            NaN                            NaN
# 593470           NaN            NaN                            NaN
#
#        Assembly Date Attorney/Representative  Average Weekly Wage  Birth Year  \
# 593466    2022-12-31                     NaN                  NaN         NaN
# 593467    2022-12-31                       N                  0.0      1950.0
# 593468    2022-12-31                     NaN                  NaN         NaN
# 593469    2022-12-31                     NaN                  NaN         NaN
# 593470    2022-12-31                     NaN                  NaN         NaN
#
#           C-2 Date C-3 Date                   Carrier Name  ...  \
# 593466         NaN      NaN                            NaN  ...
# 593467  2022-12-31      NaN  TECHNOLOGY INSURANCE CO. INC.  ...
# 593468         NaN      NaN                            NaN  ...
# 593469         NaN      NaN                            NaN  ...
# 593470         NaN      NaN                            NaN  ...
#
#        WCIO Cause of Injury Code  WCIO Cause of Injury Description  \
# 593466                       NaN                               NaN
# 593467                      25.0  FROM DIFFERENT LEVEL (ELEVATION)
# 593468                       NaN                               NaN
# 593469                       NaN                               NaN
# 593470                       NaN                               NaN
#
#        WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# 593466                        NaN                               NaN
# 593467                       90.0   MULTIPLE PHYSICAL INJURIES ONLY
# 593468                        NaN                               NaN
# 593469                        NaN                               NaN
# 593470                        NaN                               NaN
#
#        WCIO Part Of Body Code WCIO Part Of Body Description Zip Code  \
# 593466                    NaN                           NaN      NaN
# 593467                   -9.0                      MULTIPLE    12779
# 593468                    NaN                           NaN      NaN
# 593469                    NaN                           NaN      NaN
# 593470                    NaN                           NaN      NaN
#
#        Agreement Reached      WCB Decision  Number of Dependents
# 593466               NaN               NaN                   NaN
# 593467               0.0  Not Work Related                   3.0
# 593468               NaN               NaN                   NaN
# 593469               NaN               NaN                   NaN
# 593470               NaN               NaN                   NaN
#
# [5 rows x 33 columns]
#        Accident Date  Age at Injury Alternative Dispute Resolution  \
# 387970    2012-09-12             52                              N
# 387971    2024-05-22             59                              N
# 387972    2024-05-06             45                              N
# 387973    2024-02-24             42                              N
# 387974           NaN              0                              N
#
#        Assembly Date Attorney/Representative  Average Weekly Wage  Birth Year  \
# 387970    2024-06-05                       N                  NaN      1960.0
# 387971    2024-06-05                       Y                  0.0      1965.0
# 387972    2024-06-05                       Y                  0.0      1979.0
# 387973    2024-06-05                       Y                  0.0      1981.0
# 387974    2024-06-05                       Y                  0.0         NaN
#
#           C-2 Date    C-3 Date                   Carrier Name  ...  \
# 387970  2012-10-23         NaN           STATE INSURANCE FUND  ...
# 387971         NaN  2024-05-28          NYC TRANSIT AUTHORITY  ...
# 387972         NaN         NaN           STATE INSURANCE FUND  ...
# 387973         NaN  2024-05-21  NEW YORK BLACK CAR OPERATORS'  ...
# 387974         NaN  2024-05-28   CNY OTHER THAN ED, HED WATER  ...
#
#        Medical Fee Region  OIICS Nature of Injury Description  \
# 387970                  I                                 NaN
# 387971                 IV                                 NaN
# 387972                 IV                                 NaN
# 387973                 IV                                 NaN
# 387974                 IV                                 NaN
#
#        WCIO Cause of Injury Code WCIO Cause of Injury Description  \
# 387970                       NaN                              NaN
# 387971                       NaN                              NaN
# 387972                       NaN                              NaN
# 387973                       NaN                              NaN
# 387974                       NaN                              NaN
#
#        WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# 387970                        NaN                               NaN
# 387971                        NaN                               NaN
# 387972                        NaN                               NaN
# 387973                        NaN                               NaN
# 387974                        NaN                               NaN
#
#        WCIO Part Of Body Code  WCIO Part Of Body Description  Zip Code  \
# 387970                    NaN                            NaN     13619
# 387971                    NaN                            NaN     11776
# 387972                    NaN                            NaN     11368
# 387973                    NaN                            NaN     11432
# 387974                    NaN                            NaN     10302
#
#        Number of Dependents
# 387970                    5
# 387971                    1
# 387972                    5
# 387973                    5
# 387974                    5
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Descriptive analysis

# %%
# set "Claim Identifier" as the index for the train and test datasets
train_data = train_data.set_index("Claim Identifier")
test_data = test_data.set_index("Claim Identifier")

# %%
train_data.columns.values
# Out:
# array(['Accident Date', 'Age at Injury', 'Alternative Dispute Resolution',
#        'Assembly Date', 'Attorney/Representative', 'Average Weekly Wage',
#        'Birth Year', 'C-2 Date', 'C-3 Date', 'Carrier Name',
#        'Carrier Type', 'Claim Injury Type', 'County of Injury',
#        'COVID-19 Indicator', 'District Name', 'First Hearing Date',
#        'Gender', 'IME-4 Count', 'Industry Code',
#        'Industry Code Description', 'Medical Fee Region',
#        'OIICS Nature of Injury Description', 'WCIO Cause of Injury Code',
#        'WCIO Cause of Injury Description', 'WCIO Nature of Injury Code',
#        'WCIO Nature of Injury Description', 'WCIO Part Of Body Code',
#        'WCIO Part Of Body Description', 'Zip Code', 'Agreement Reached',
#        'WCB Decision', 'Number of Dependents'], dtype=object)

# %%
train_data.describe(include="all").T
# Out:
#                                        count unique  \
# Accident Date                         570337   5539
# Age at Injury                       574026.0    NaN
# Alternative Dispute Resolution        574026      3
# Assembly Date                         593471   1096
# Attorney/Representative               574026      2
# Average Weekly Wage                 545375.0    NaN
# Birth Year                          544948.0    NaN
# C-2 Date                              559466   2475
# C-3 Date                              187245   1648
# Carrier Name                          574026   2046
# Carrier Type                          574026      8
# Claim Injury Type                     574026      8
# County of Injury                      574026     63
# COVID-19 Indicator                    574026      2
# District Name                         574026      8
# First Hearing Date                    150798   1094
# Gender                                574026      4
# IME-4 Count                         132803.0    NaN
# Industry Code                       564068.0    NaN
# Industry Code Description             564068     20
# Medical Fee Region                    574026      5
# OIICS Nature of Injury Description       0.0    NaN
# WCIO Cause of Injury Code           558386.0    NaN
# WCIO Cause of Injury Description      558386     74
# WCIO Nature of Injury Code          558369.0    NaN
# WCIO Nature of Injury Description     558369     56
# WCIO Part Of Body Code              556944.0    NaN
# WCIO Part Of Body Description         556944     54
# Zip Code                              545389   8286
# Agreement Reached                   574026.0    NaN
# WCB Decision                          574026      1
# Number of Dependents                574026.0    NaN
#
#                                                                   top    freq  \
# Accident Date                                              2020-03-01    1245
# Age at Injury                                                     NaN     NaN
# Alternative Dispute Resolution                                      N  571412
# Assembly Date                                              2020-03-06    1422
# Attorney/Representative                                             N  392291
# Average Weekly Wage                                               NaN     NaN
# Birth Year                                                        NaN     NaN
# C-2 Date                                                   2021-05-11    1847
# C-3 Date                                                   2021-04-21     350
# Carrier Name                                     STATE INSURANCE FUND  111144
# Carrier Type                                              1A. PRIVATE  285368
# Claim Injury Type                                         2. NON-COMP  291078
# County of Injury                                              SUFFOLK   60430
# COVID-19 Indicator                                                  N  546505
# District Name                                                     NYC  270779
# First Hearing Date                                         2022-04-15     440
# Gender                                                              M  335218
# IME-4 Count                                                       NaN     NaN
# Industry Code                                                     NaN     NaN
# Industry Code Description           HEALTH CARE AND SOCIAL ASSISTANCE  114339
# Medical Fee Region                                                 IV  265981
# OIICS Nature of Injury Description                                NaN     NaN
# WCIO Cause of Injury Code                                         NaN     NaN
# WCIO Cause of Injury Description                              LIFTING   46610
# WCIO Nature of Injury Code                                        NaN     NaN
# WCIO Nature of Injury Description                      STRAIN OR TEAR  153373
# WCIO Part Of Body Code                                            NaN     NaN
# WCIO Part Of Body Description                         LOWER BACK AREA   51862
# Zip Code                                                        11236    3398
# Agreement Reached                                                 NaN     NaN
# WCB Decision                                         Not Work Related  574026
# Number of Dependents                                              NaN     NaN
#
#                                            mean         std   min     25%  \
# Accident Date                               NaN         NaN   NaN     NaN
# Age at Injury                          42.11427   14.256432   0.0    31.0
# Alternative Dispute Resolution              NaN         NaN   NaN     NaN
# Assembly Date                               NaN         NaN   NaN     NaN
# Attorney/Representative                     NaN         NaN   NaN     NaN
# Average Weekly Wage                  491.088321  6092.91812   0.0     0.0
# Birth Year                          1886.767604  414.644423   0.0  1965.0
# C-2 Date                                    NaN         NaN   NaN     NaN
# C-3 Date                                    NaN         NaN   NaN     NaN
# Carrier Name                                NaN         NaN   NaN     NaN
# Carrier Type                                NaN         NaN   NaN     NaN
# Claim Injury Type                           NaN         NaN   NaN     NaN
# County of Injury                            NaN         NaN   NaN     NaN
# COVID-19 Indicator                          NaN         NaN   NaN     NaN
# District Name                               NaN         NaN   NaN     NaN
# First Hearing Date                          NaN         NaN   NaN     NaN
# Gender                                      NaN         NaN   NaN     NaN
# IME-4 Count                            3.207337    2.832303   1.0     1.0
# Industry Code                         58.645305   19.644175  11.0    45.0
# Industry Code Description                   NaN         NaN   NaN     NaN
# Medical Fee Region                          NaN         NaN   NaN     NaN
# OIICS Nature of Injury Description          NaN         NaN   NaN     NaN
# WCIO Cause of Injury Code             54.381143   25.874281   1.0    31.0
# WCIO Cause of Injury Description            NaN         NaN   NaN     NaN
# WCIO Nature of Injury Code            41.013839   22.207521   1.0    16.0
# WCIO Nature of Injury Description           NaN         NaN   NaN     NaN
# WCIO Part Of Body Code                39.738146    22.36594  -9.0    33.0
# WCIO Part Of Body Description               NaN         NaN   NaN     NaN
# Zip Code                                    NaN         NaN   NaN     NaN
# Agreement Reached                      0.046665    0.210921   0.0     0.0
# WCB Decision                                NaN         NaN   NaN     NaN
# Number of Dependents                   3.006559    2.000801   0.0     1.0
#
#                                        50%     75%        max
# Accident Date                          NaN     NaN        NaN
# Age at Injury                         42.0    54.0      117.0
# Alternative Dispute Resolution         NaN     NaN        NaN
# Assembly Date                          NaN     NaN        NaN
# Attorney/Representative                NaN     NaN        NaN
# Average Weekly Wage                    0.0   841.0  2828079.0
# Birth Year                          1977.0  1989.0     2018.0
# C-2 Date                               NaN     NaN        NaN
# C-3 Date                               NaN     NaN        NaN
# Carrier Name                           NaN     NaN        NaN
# Carrier Type                           NaN     NaN        NaN
# Claim Injury Type                      NaN     NaN        NaN
# County of Injury                       NaN     NaN        NaN
# COVID-19 Indicator                     NaN     NaN        NaN
# District Name                          NaN     NaN        NaN
# First Hearing Date                     NaN     NaN        NaN
# Gender                                 NaN     NaN        NaN
# IME-4 Count                            2.0     4.0       73.0
# Industry Code                         61.0    71.0       92.0
# Industry Code Description              NaN     NaN        NaN
# Medical Fee Region                     NaN     NaN        NaN
# OIICS Nature of Injury Description     NaN     NaN        NaN
# WCIO Cause of Injury Code             56.0    75.0       99.0
# WCIO Cause of Injury Description       NaN     NaN        NaN
# WCIO Nature of Injury Code            49.0    52.0       91.0
# WCIO Nature of Injury Description      NaN     NaN        NaN
# WCIO Part Of Body Code                38.0    53.0       99.0
# WCIO Part Of Body Description          NaN     NaN        NaN
# Zip Code                               NaN     NaN        NaN
# Agreement Reached                      0.0     0.0        1.0
# WCB Decision                           NaN     NaN        NaN
# Number of Dependents                   3.0     5.0        6.0

# %%
train_data.info()

## DATA TYPES:
# Convert accident date (to date type)
# convert age (to int)
# Alternative dispute resolution (??)
# Assembly date (to date type)
# birth year (to int)
# C2 date (to date type)
# C3 date (to date type)
# First hearing date (to date)
# IME-4 count (to int)
# Industry code (object)
# OIICS Nature of Injury Description (to object) - all nulls (relevant??)
# WCIO cause of injury code (float to object)
# WCIO Nature of Injury Code (float to object)
# WCIO Part Of Body Code (float to object)
# Agreement reached (??) - boolean/ int(???)
# Number of dependents (to int)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 593471 entries, 5393875 to 818961390
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Accident Date                       570337 non-null  object
#  1   Age at Injury                       574026 non-null  float64
#  2   Alternative Dispute Resolution      574026 non-null  object
#  3   Assembly Date                       593471 non-null  object
#  4   Attorney/Representative             574026 non-null  object
#  5   Average Weekly Wage                 545375 non-null  float64
#  6   Birth Year                          544948 non-null  float64
#  7   C-2 Date                            559466 non-null  object
#  8   C-3 Date                            187245 non-null  object
#  9   Carrier Name                        574026 non-null  object
#  10  Carrier Type                        574026 non-null  object
#  11  Claim Injury Type                   574026 non-null  object
#  12  County of Injury                    574026 non-null  object
#  13  COVID-19 Indicator                  574026 non-null  object
#  14  District Name                       574026 non-null  object
#  15  First Hearing Date                  150798 non-null  object
#  16  Gender                              574026 non-null  object
#  17  IME-4 Count                         132803 non-null  float64
#  18  Industry Code                       564068 non-null  float64
#  19  Industry Code Description           564068 non-null  object
#  20  Medical Fee Region                  574026 non-null  object
#  21  OIICS Nature of Injury Description  0 non-null       float64
#  22  WCIO Cause of Injury Code           558386 non-null  float64
#  23  WCIO Cause of Injury Description    558386 non-null  object
#  24  WCIO Nature of Injury Code          558369 non-null  float64
#  25  WCIO Nature of Injury Description   558369 non-null  object
#  26  WCIO Part Of Body Code              556944 non-null  float64
#  27  WCIO Part Of Body Description       556944 non-null  object
#  28  Zip Code                            545389 non-null  object
#  29  Agreement Reached                   574026 non-null  float64
#  30  WCB Decision                        574026 non-null  object
#  31  Number of Dependents                574026 non-null  float64
# dtypes: float64(11), object(21)
# memory usage: 149.4+ MB

# %% [markdown]
# #### Check for duplicates & missing values in target variable:

# %%
duplicates =train_data.duplicated().value_counts()
duplicates
# Out:
# False    575121
# True      18350
# Name: count, dtype: int64

# %%
train_data["Claim Injury Type"].unique()
# Out:
# array(['2. NON-COMP', '4. TEMPORARY', nan, '3. MED ONLY',
#        '5. PPD SCH LOSS', '6. PPD NSL', '1. CANCELLED', '8. DEATH',
#        '7. PTD'], dtype=object)

# %%
missing_data_target = train_data[train_data['Claim Injury Type'].isna()]
missing_data_target.head()
# Out:
#                  Accident Date  Age at Injury Alternative Dispute Resolution  \
# Claim Identifier
# 957648180                  NaN            NaN                            NaN
# 363651794                  NaN            NaN                            NaN
# 209507552                  NaN            NaN                            NaN
# 970865999                  NaN            NaN                            NaN
# 807753247                  NaN            NaN                            NaN
#
#                  Assembly Date Attorney/Representative  Average Weekly Wage  \
# Claim Identifier
# 957648180           2020-01-01                     NaN                  NaN
# 363651794           2020-01-01                     NaN                  NaN
# 209507552           2020-01-01                     NaN                  NaN
# 970865999           2020-01-01                     NaN                  NaN
# 807753247           2020-01-01                     NaN                  NaN
#
#                   Birth Year C-2 Date C-3 Date Carrier Name  ...  \
# Claim Identifier                                             ...
# 957648180                NaN      NaN      NaN          NaN  ...
# 363651794                NaN      NaN      NaN          NaN  ...
# 209507552                NaN      NaN      NaN          NaN  ...
# 970865999                NaN      NaN      NaN          NaN  ...
# 807753247                NaN      NaN      NaN          NaN  ...
#
#                  WCIO Cause of Injury Code WCIO Cause of Injury Description  \
# Claim Identifier
# 957648180                              NaN                              NaN
# 363651794                              NaN                              NaN
# 209507552                              NaN                              NaN
# 970865999                              NaN                              NaN
# 807753247                              NaN                              NaN
#
#                  WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# Claim Identifier
# 957648180                               NaN                               NaN
# 363651794                               NaN                               NaN
# 209507552                               NaN                               NaN
# 970865999                               NaN                               NaN
# 807753247                               NaN                               NaN
#
#                  WCIO Part Of Body Code WCIO Part Of Body Description  \
# Claim Identifier
# 957648180                           NaN                           NaN
# 363651794                           NaN                           NaN
# 209507552                           NaN                           NaN
# 970865999                           NaN                           NaN
# 807753247                           NaN                           NaN
#
#                  Zip Code  Agreement Reached  WCB Decision  \
# Claim Identifier
# 957648180             NaN                NaN           NaN
# 363651794             NaN                NaN           NaN
# 209507552             NaN                NaN           NaN
# 970865999             NaN                NaN           NaN
# 807753247             NaN                NaN           NaN
#
#                  Number of Dependents
# Claim Identifier
# 957648180                         NaN
# 363651794                         NaN
# 209507552                         NaN
# 970865999                         NaN
# 807753247                         NaN
#
# [5 rows x 32 columns]

# %%
missing_data_target.info()
# all features with missing values on the target, are also missing, except Assembly Date -> not relevant (decision -> drop rows)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19445 entries, 957648180 to 818961390
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Accident Date                       0 non-null      object
#  1   Age at Injury                       0 non-null      float64
#  2   Alternative Dispute Resolution      0 non-null      object
#  3   Assembly Date                       19445 non-null  object
#  4   Attorney/Representative             0 non-null      object
#  5   Average Weekly Wage                 0 non-null      float64
#  6   Birth Year                          0 non-null      float64
#  7   C-2 Date                            0 non-null      object
#  8   C-3 Date                            0 non-null      object
#  9   Carrier Name                        0 non-null      object
#  10  Carrier Type                        0 non-null      object
#  11  Claim Injury Type                   0 non-null      object
#  12  County of Injury                    0 non-null      object
#  13  COVID-19 Indicator                  0 non-null      object
#  14  District Name                       0 non-null      object
#  15  First Hearing Date                  0 non-null      object
#  16  Gender                              0 non-null      object
#  17  IME-4 Count                         0 non-null      float64
#  18  Industry Code                       0 non-null      float64
#  19  Industry Code Description           0 non-null      object
#  20  Medical Fee Region                  0 non-null      object
#  21  OIICS Nature of Injury Description  0 non-null      float64
#  22  WCIO Cause of Injury Code           0 non-null      float64
#  23  WCIO Cause of Injury Description    0 non-null      object
#  24  WCIO Nature of Injury Code          0 non-null      float64
#  25  WCIO Nature of Injury Description   0 non-null      object
#  26  WCIO Part Of Body Code              0 non-null      float64
#  27  WCIO Part Of Body Description       0 non-null      object
#  28  Zip Code                            0 non-null      object
#  29  Agreement Reached                   0 non-null      float64
#  30  WCB Decision                        0 non-null      object
#  31  Number of Dependents                0 non-null      float64
# dtypes: float64(11), object(21)
# memory usage: 4.9+ MB

# %% [markdown]
# #### Drop 'OIICS Nature of Injury Description' feature & rows with missing target values

# %%
train_data = train_data.drop(missing_data_target.index)

# %%
train_data=train_data.drop(['OIICS Nature of Injury Description'], axis=1)

# %% [markdown]
# #### Re-Check for duplicates

# %%
# check for duplicate values on train and test dataset:
print(f"Train dataset:\n{train_data.duplicated().value_counts()}") # true: nr of duplicated rows in dataset
# Out:
# Train dataset:
# False    574025
# True          1
# Name: count, dtype: int64

# %%
# Check the percentage of duplicates for the entire training dataset
train_data.duplicated().mean()*100
# conclusion: Not relevant for analysis, drop duplicates
# Out:
# 0.00017420813691365895

# %%
train_data.drop_duplicates(inplace=True)
train_data.duplicated().value_counts()
# Remove duplicates
# Out:
# False    574025
# Name: count, dtype: int64

# %% [markdown]
# #### Re check descriptives:

# %%
train_data.describe(include="all").T
# Out:
#                                       count unique  \
# Accident Date                        570337   5539
# Age at Injury                      574025.0    NaN
# Alternative Dispute Resolution       574025      3
# Assembly Date                        574025    897
# Attorney/Representative              574025      2
# Average Weekly Wage                545374.0    NaN
# Birth Year                         544947.0    NaN
# C-2 Date                             559466   2475
# C-3 Date                             187244   1648
# Carrier Name                         574025   2046
# Carrier Type                         574025      8
# Claim Injury Type                    574025      8
# County of Injury                     574025     63
# COVID-19 Indicator                   574025      2
# District Name                        574025      8
# First Hearing Date                   150797   1094
# Gender                               574025      4
# IME-4 Count                        132803.0    NaN
# Industry Code                      564068.0    NaN
# Industry Code Description            564068     20
# Medical Fee Region                   574025      5
# WCIO Cause of Injury Code          558386.0    NaN
# WCIO Cause of Injury Description     558386     74
# WCIO Nature of Injury Code         558369.0    NaN
# WCIO Nature of Injury Description    558369     56
# WCIO Part Of Body Code             556944.0    NaN
# WCIO Part Of Body Description        556944     54
# Zip Code                             545388   8286
# Agreement Reached                  574025.0    NaN
# WCB Decision                         574025      1
# Number of Dependents               574025.0    NaN
#
#                                                                  top    freq  \
# Accident Date                                             2020-03-01    1245
# Age at Injury                                                    NaN     NaN
# Alternative Dispute Resolution                                     N  571411
# Assembly Date                                             2020-03-06    1413
# Attorney/Representative                                            N  392291
# Average Weekly Wage                                              NaN     NaN
# Birth Year                                                       NaN     NaN
# C-2 Date                                                  2021-05-11    1847
# C-3 Date                                                  2021-04-21     350
# Carrier Name                                    STATE INSURANCE FUND  111144
# Carrier Type                                             1A. PRIVATE  285367
# Claim Injury Type                                        2. NON-COMP  291078
# County of Injury                                             SUFFOLK   60430
# COVID-19 Indicator                                                 N  546504
# District Name                                                    NYC  270778
# First Hearing Date                                        2022-04-15     440
# Gender                                                             M  335217
# IME-4 Count                                                      NaN     NaN
# Industry Code                                                    NaN     NaN
# Industry Code Description          HEALTH CARE AND SOCIAL ASSISTANCE  114339
# Medical Fee Region                                                IV  265981
# WCIO Cause of Injury Code                                        NaN     NaN
# WCIO Cause of Injury Description                             LIFTING   46610
# WCIO Nature of Injury Code                                       NaN     NaN
# WCIO Nature of Injury Description                     STRAIN OR TEAR  153373
# WCIO Part Of Body Code                                           NaN     NaN
# WCIO Part Of Body Description                        LOWER BACK AREA   51862
# Zip Code                                                       11236    3398
# Agreement Reached                                                NaN     NaN
# WCB Decision                                        Not Work Related  574025
# Number of Dependents                                             NaN     NaN
#
#                                           mean         std   min     25%  \
# Accident Date                              NaN         NaN   NaN     NaN
# Age at Injury                        42.114343   14.256336   0.0    31.0
# Alternative Dispute Resolution             NaN         NaN   NaN     NaN
# Assembly Date                              NaN         NaN   NaN     NaN
# Attorney/Representative                    NaN         NaN   NaN     NaN
# Average Weekly Wage                 491.089221  6092.92367   0.0     0.0
# Birth Year                         1886.767454  414.644789   0.0  1965.0
# C-2 Date                                   NaN         NaN   NaN     NaN
# C-3 Date                                   NaN         NaN   NaN     NaN
# Carrier Name                               NaN         NaN   NaN     NaN
# Carrier Type                               NaN         NaN   NaN     NaN
# Claim Injury Type                          NaN         NaN   NaN     NaN
# County of Injury                           NaN         NaN   NaN     NaN
# COVID-19 Indicator                         NaN         NaN   NaN     NaN
# District Name                              NaN         NaN   NaN     NaN
# First Hearing Date                         NaN         NaN   NaN     NaN
# Gender                                     NaN         NaN   NaN     NaN
# IME-4 Count                           3.207337    2.832303   1.0     1.0
# Industry Code                        58.645305   19.644175  11.0    45.0
# Industry Code Description                  NaN         NaN   NaN     NaN
# Medical Fee Region                         NaN         NaN   NaN     NaN
# WCIO Cause of Injury Code            54.381143   25.874281   1.0    31.0
# WCIO Cause of Injury Description           NaN         NaN   NaN     NaN
# WCIO Nature of Injury Code           41.013839   22.207521   1.0    16.0
# WCIO Nature of Injury Description          NaN         NaN   NaN     NaN
# WCIO Part Of Body Code               39.738146    22.36594  -9.0    33.0
# WCIO Part Of Body Description              NaN         NaN   NaN     NaN
# Zip Code                                   NaN         NaN   NaN     NaN
# Agreement Reached                     0.046665    0.210921   0.0     0.0
# WCB Decision                               NaN         NaN   NaN     NaN
# Number of Dependents                  3.006564    2.000799   0.0     1.0
#
#                                       50%     75%        max
# Accident Date                         NaN     NaN        NaN
# Age at Injury                        42.0    54.0      117.0
# Alternative Dispute Resolution        NaN     NaN        NaN
# Assembly Date                         NaN     NaN        NaN
# Attorney/Representative               NaN     NaN        NaN
# Average Weekly Wage                   0.0   841.0  2828079.0
# Birth Year                         1977.0  1989.0     2018.0
# C-2 Date                              NaN     NaN        NaN
# C-3 Date                              NaN     NaN        NaN
# Carrier Name                          NaN     NaN        NaN
# Carrier Type                          NaN     NaN        NaN
# Claim Injury Type                     NaN     NaN        NaN
# County of Injury                      NaN     NaN        NaN
# COVID-19 Indicator                    NaN     NaN        NaN
# District Name                         NaN     NaN        NaN
# First Hearing Date                    NaN     NaN        NaN
# Gender                                NaN     NaN        NaN
# IME-4 Count                           2.0     4.0       73.0
# Industry Code                        61.0    71.0       92.0
# Industry Code Description             NaN     NaN        NaN
# Medical Fee Region                    NaN     NaN        NaN
# WCIO Cause of Injury Code            56.0    75.0       99.0
# WCIO Cause of Injury Description      NaN     NaN        NaN
# WCIO Nature of Injury Code           49.0    52.0       91.0
# WCIO Nature of Injury Description     NaN     NaN        NaN
# WCIO Part Of Body Code               38.0    53.0       99.0
# WCIO Part Of Body Description         NaN     NaN        NaN
# Zip Code                              NaN     NaN        NaN
# Agreement Reached                     0.0     0.0        1.0
# WCB Decision                          NaN     NaN        NaN
# Number of Dependents                  3.0     5.0        6.0

# %% [markdown]
# #### Missing Values: (Drop/Don't drop??)

# %%
# Check for missing values on train dataset: 
missing_values_train = train_data.isna().sum()
missing_values_train_percentage = (train_data.isna().mean()*100).round(2)
print("Missing values\n",missing_values_train,"\n")
print("Percentage of Missing values\n",missing_values_train_percentage)
# Out:
# Missing values
#  Accident Date                          3688
# Age at Injury                             0
# Alternative Dispute Resolution            0
# Assembly Date                             0
# Attorney/Representative                   0
# Average Weekly Wage                   28651
# Birth Year                            29078
# C-2 Date                              14559
# C-3 Date                             386781
# Carrier Name                              0
# Carrier Type                              0
# Claim Injury Type                         0
# County of Injury                          0
# COVID-19 Indicator                        0
# District Name                             0
# First Hearing Date                   423228
# Gender                                    0
# IME-4 Count                          441222
# Industry Code                          9957
# Industry Code Description              9957
# Medical Fee Region                        0
# WCIO Cause of Injury Code             15639
# WCIO Cause of Injury Description      15639
# WCIO Nature of Injury Code            15656
# WCIO Nature of Injury Description     15656
# WCIO Part Of Body Code                17081
# WCIO Part Of Body Description         17081
# Zip Code                              28637
# Agreement Reached                         0
# WCB Decision                              0
# Number of Dependents                      0
# dtype: int64
#
# Percentage of Missing values
#  Accident Date                         0.64
# Age at Injury                         0.00
# Alternative Dispute Resolution        0.00
# Assembly Date                         0.00
# Attorney/Representative               0.00
# Average Weekly Wage                   4.99
# Birth Year                            5.07
# C-2 Date                              2.54
# C-3 Date                             67.38
# Carrier Name                          0.00
# Carrier Type                          0.00
# Claim Injury Type                     0.00
# County of Injury                      0.00
# COVID-19 Indicator                    0.00
# District Name                         0.00
# First Hearing Date                   73.73
# Gender                                0.00
# IME-4 Count                          76.86
# Industry Code                         1.73
# Industry Code Description             1.73
# Medical Fee Region                    0.00
# WCIO Cause of Injury Code             2.72
# WCIO Cause of Injury Description      2.72
# WCIO Nature of Injury Code            2.73
# WCIO Nature of Injury Description     2.73
# WCIO Part Of Body Code                2.98
# WCIO Part Of Body Description         2.98
# Zip Code                              4.99
# Agreement Reached                     0.00
# WCB Decision                          0.00
# Number of Dependents                  0.00
# dtype: float64

# %% [markdown]
# #### - Unique values (search for strange values)

# %%
train_data.columns.values
# Out:
# array(['Accident Date', 'Age at Injury', 'Alternative Dispute Resolution',
#        'Assembly Date', 'Attorney/Representative', 'Average Weekly Wage',
#        'Birth Year', 'C-2 Date', 'C-3 Date', 'Carrier Name',
#        'Carrier Type', 'Claim Injury Type', 'County of Injury',
#        'COVID-19 Indicator', 'District Name', 'First Hearing Date',
#        'Gender', 'IME-4 Count', 'Industry Code',
#        'Industry Code Description', 'Medical Fee Region',
#        'WCIO Cause of Injury Code', 'WCIO Cause of Injury Description',
#        'WCIO Nature of Injury Code', 'WCIO Nature of Injury Description',
#        'WCIO Part Of Body Code', 'WCIO Part Of Body Description',
#        'Zip Code', 'Agreement Reached', 'WCB Decision',
#        'Number of Dependents'], dtype=object)

# %%
train_data.shape
# Out:
# (574025, 31)

# %%
train_data["Claim Injury Type"].unique().tolist()
# Accident date
# Age at injury (0)????
# Alternative dispute resolution (U ??)
# Attorney representative (no issues)
# avg weekly wage (didn't check)
# Birth year (0), (2018 - baby)???
# carrier names - check if carrier names are weird (like general business names - walmart??)
# Carrier type: 'UNKNOWN'/ 5D. SPECIAL FUND - UNKNOWN (no issues)
# Claim injury type (cancelled ??)
#County of injury (unknown)
# Covid19 (no issues)
# district name ("Statewide")
# Gender ("U", "X")
# IME-4 Count (no issues - outlier)
# Industry code (no issues)
# Industry code description (no issues)
# Medical Fee region (UK??)
# OIICS Nature of Injury description (no values) --> removed 
# WCIO Cause of Injury Code (no issues)
# WCIO Cause of Injury Description(no issues)
# WCIO Nature of Injury Code (no issues)
# WCIO Nature of Injury Description (no issues)
# WCIO Part Of Body Code (n issues)
# WCIO Part Of Body Description ("Insufficient info to properly classify")
# Zip Code (no issues)
# Agreement Reached (no issues)
# WCB Decision (no issues)
# Number of Dependents (no issues)
# Out:
# ['2. NON-COMP',
#  '4. TEMPORARY',
#  '3. MED ONLY',
#  '5. PPD SCH LOSS',
#  '6. PPD NSL',
#  '1. CANCELLED',
#  '8. DEATH',
#  '7. PTD']

# %% [markdown]
# #### Data types:

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 574025 entries, 5393875 to 6165075
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Accident Date                      570337 non-null  object
#  1   Age at Injury                      574025 non-null  float64
#  2   Alternative Dispute Resolution     574025 non-null  object
#  3   Assembly Date                      574025 non-null  object
#  4   Attorney/Representative            574025 non-null  object
#  5   Average Weekly Wage                545374 non-null  float64
#  6   Birth Year                         544947 non-null  float64
#  7   C-2 Date                           559466 non-null  object
#  8   C-3 Date                           187244 non-null  object
#  9   Carrier Name                       574025 non-null  object
#  10  Carrier Type                       574025 non-null  object
#  11  Claim Injury Type                  574025 non-null  object
#  12  County of Injury                   574025 non-null  object
#  13  COVID-19 Indicator                 574025 non-null  object
#  14  District Name                      574025 non-null  object
#  15  First Hearing Date                 150797 non-null  object
#  16  Gender                             574025 non-null  object
#  17  IME-4 Count                        132803 non-null  float64
#  18  Industry Code                      564068 non-null  float64
#  19  Industry Code Description          564068 non-null  object
#  20  Medical Fee Region                 574025 non-null  object
#  21  WCIO Cause of Injury Code          558386 non-null  float64
#  22  WCIO Cause of Injury Description   558386 non-null  object
#  23  WCIO Nature of Injury Code         558369 non-null  float64
#  24  WCIO Nature of Injury Description  558369 non-null  object
#  25  WCIO Part Of Body Code             556944 non-null  float64
#  26  WCIO Part Of Body Description      556944 non-null  object
#  27  Zip Code                           545388 non-null  object
#  28  Agreement Reached                  574025 non-null  float64
#  29  WCB Decision                       574025 non-null  object
#  30  Number of Dependents               574025 non-null  float64
# dtypes: float64(10), object(21)
# memory usage: 140.1+ MB

# %%
train_data["Age at Injury"] = train_data["Age at Injury"].astype("Int64")

# %%
train_data["Number of Dependents"] = train_data["Number of Dependents"].astype("Int64")

# %%
train_data["Birth Year"] = train_data["Birth Year"].astype("Int64")

# %%
train_data["WCIO Part Of Body Code"] = train_data["WCIO Part Of Body Code"].astype("Int64")

# %%
train_data["WCIO Nature of Injury Code"] = train_data["WCIO Nature of Injury Code"].astype("Int64")

# %%
train_data["WCIO Cause of Injury Code"] = train_data["WCIO Cause of Injury Code"].astype("Int64")

# %%
train_data["Industry Code"] = train_data["Industry Code"].astype("Int64")

# %%
train_data["Accident Date"] = pd.to_datetime(train_data['Accident Date'], format = '%Y-%m-%d')

# %%
train_data["Assembly Date"] = pd.to_datetime(train_data['C-2 Date'], format = '%Y-%m-%d')

# %%
train_data["First Hearing Date"] = pd.to_datetime(train_data['First Hearing Date'], format = '%Y-%m-%d')

# %%
train_data["C-2 Date"] = pd.to_datetime(train_data['C-2 Date'], format = '%Y-%m-%d')

# %%
train_data["C-3 Date"] = pd.to_datetime(train_data['C-3 Date'], format = '%Y-%m-%d')

# %%
train_data["IME-4 Count"] = train_data["IME-4 Count"].astype("Int64")

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 574025 entries, 5393875 to 6165075
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Accident Date                      570337 non-null  datetime64[ns]
#  1   Age at Injury                      574025 non-null  Int64
#  2   Alternative Dispute Resolution     574025 non-null  object
#  3   Assembly Date                      559466 non-null  datetime64[ns]
#  4   Attorney/Representative            574025 non-null  object
#  5   Average Weekly Wage                545374 non-null  float64
#  6   Birth Year                         544947 non-null  Int64
#  7   C-2 Date                           559466 non-null  datetime64[ns]
#  8   C-3 Date                           187244 non-null  datetime64[ns]
#  9   Carrier Name                       574025 non-null  object
#  10  Carrier Type                       574025 non-null  object
#  11  Claim Injury Type                  574025 non-null  object
#  12  County of Injury                   574025 non-null  object
#  13  COVID-19 Indicator                 574025 non-null  object
#  14  District Name                      574025 non-null  object
#  15  First Hearing Date                 150797 non-null  datetime64[ns]
#  16  Gender                             574025 non-null  object
#  17  IME-4 Count                        132803 non-null  Int64
#  18  Industry Code                      564068 non-null  Int64
#  19  Industry Code Description          564068 non-null  object
#  20  Medical Fee Region                 574025 non-null  object
#  21  WCIO Cause of Injury Code          558386 non-null  Int64
#  22  WCIO Cause of Injury Description   558386 non-null  object
#  23  WCIO Nature of Injury Code         558369 non-null  Int64
#  24  WCIO Nature of Injury Description  558369 non-null  object
#  25  WCIO Part Of Body Code             556944 non-null  Int64
#  26  WCIO Part Of Body Description      556944 non-null  object
#  27  Zip Code                           545388 non-null  object
#  28  Agreement Reached                  574025 non-null  float64
#  29  WCB Decision                       574025 non-null  object
#  30  Number of Dependents               574025 non-null  Int64
# dtypes: Int64(8), datetime64[ns](5), float64(2), object(16)
# memory usage: 144.5+ MB

# %%
train_data["Agreement Reached"].head()
# Out:
# Claim Identifier
# 5393875    0.0
# 5393091    1.0
# 5393889    0.0
# 5393887    0.0
# 5393863    0.0
# Name: Agreement Reached, dtype: float64

# %%
train_data.columns.values
# Out:
# array(['Accident Date', 'Age at Injury', 'Alternative Dispute Resolution',
#        'Assembly Date', 'Attorney/Representative', 'Average Weekly Wage',
#        'Birth Year', 'C-2 Date', 'C-3 Date', 'Carrier Name',
#        'Carrier Type', 'Claim Injury Type', 'County of Injury',
#        'COVID-19 Indicator', 'District Name', 'First Hearing Date',
#        'Gender', 'IME-4 Count', 'Industry Code',
#        'Industry Code Description', 'Medical Fee Region',
#        'WCIO Cause of Injury Code', 'WCIO Cause of Injury Description',
#        'WCIO Nature of Injury Code', 'WCIO Nature of Injury Description',
#        'WCIO Part Of Body Code', 'WCIO Part Of Body Description',
#        'Zip Code', 'Agreement Reached', 'WCB Decision',
#        'Number of Dependents'], dtype=object)

# %% [markdown]
# #### Convert birth year into age:

# %%
train_data["Birth Year"]= datetime.now().year - train_data["Birth Year"]

# %%
train_data["Claim Injury Type"].unique().tolist()
# Out:
# ['2. NON-COMP',
#  '4. TEMPORARY',
#  '3. MED ONLY',
#  '5. PPD SCH LOSS',
#  '6. PPD NSL',
#  '1. CANCELLED',
#  '8. DEATH',
#  '7. PTD']

# %% [markdown]
# #### Dates analysis:

# %%
train_data["Days Between Accident_Assembly"] = train_data['Assembly Date'] - train_data['Accident Date']
print(f"maximum days between assembly: {train_data['Days Between Accident_Assembly'].max()}")
print(f"minimum days between assembly: {train_data['Days Between Accident_Assembly'].min()}") 
# strange values assembly date < accident date?? 
# #same max & min as days between accident and C2.
# Out:
# maximum days between assembly: 21503 days 00:00:00
# minimum days between assembly: -8842 days +00:00:00

# %%
train_data["Days Between Accident_C2"] = train_data['C-2 Date'] - train_data['Accident Date']
print(f"maximum days between assembly: {train_data['Days Between Accident_C2'].max()}")
print(f"minimum days between assembly: {train_data['Days Between Accident_C2'].min()}") 
# strange values C2 date < accident date?? 
# #same max & min as days between accident and C2.
# Out:
# maximum days between assembly: 21503 days 00:00:00
# minimum days between assembly: -8842 days +00:00:00

# %%
train_data["Days Between Accident_C3"] = train_data['C-3 Date'] - train_data['Accident Date']
print(f"maximum days between assembly: {train_data['Days Between Accident_C3'].max()}")
print(f"minimum days between assembly: {train_data['Days Between Accident_C3'].min()}")
# strange values C3 date < accident date??
# Out:
# maximum days between assembly: 18566 days 00:00:00
# minimum days between assembly: -9870 days +00:00:00

# %%
train_data["Days Between Accident_1st_Hearing"] = train_data['First Hearing Date'] - train_data['Accident Date']
print(f"maximum days between assembly: {train_data["Days Between Accident_1st_Hearing"].max()}")
print(f"minimum days between assembly: {train_data["Days Between Accident_1st_Hearing"].min()}")
# strange values 1st_Hearing < accident date??
# Out:
# maximum days between assembly: 16373 days 00:00:00
# minimum days between assembly: -576 days +00:00:00

# %% [markdown]
# #### Group descriptions by code:

# %%
group_by_industry = train_data.groupby("Industry Code")["Industry Code Description"].unique()
group_by_industry

# Different codes with same description
# Out:
# Industry Code
# 11                      [AGRICULTURE, FORESTRY, FISHING AND HUNTING]
# 21                                                          [MINING]
# 22                                                       [UTILITIES]
# 23                                                    [CONSTRUCTION]
# 31                                                   [MANUFACTURING]
# 32                                                   [MANUFACTURING]
# 33                                                   [MANUFACTURING]
# 42                                                 [WHOLESALE TRADE]
# 44                                                    [RETAIL TRADE]
# 45                                                    [RETAIL TRADE]
# 48                                  [TRANSPORTATION AND WAREHOUSING]
# 49                                  [TRANSPORTATION AND WAREHOUSING]
# 51                                                     [INFORMATION]
# 52                                           [FINANCE AND INSURANCE]
# 53                              [REAL ESTATE AND RENTAL AND LEASING]
# 54                [PROFESSIONAL, SCIENTIFIC, AND TECHNICAL SERVICES]
# 55                         [MANAGEMENT OF COMPANIES AND ENTERPRISES]
# 56    [ADMINISTRATIVE AND SUPPORT AND WASTE MANAGEMENT AND REMEDIAT]
# 61                                            [EDUCATIONAL SERVICES]
# 62                               [HEALTH CARE AND SOCIAL ASSISTANCE]
# 71                             [ARTS, ENTERTAINMENT, AND RECREATION]
# 72                                 [ACCOMMODATION AND FOOD SERVICES]
# 81                   [OTHER SERVICES (EXCEPT PUBLIC ADMINISTRATION)]
# 92                                           [PUBLIC ADMINISTRATION]
# Name: Industry Code Description, dtype: object

# %%
group_by_injury = train_data.groupby("WCIO Cause of Injury Code")["WCIO Cause of Injury Description"].unique()
group_by_injury

# Different codes with same description
# Out:
# WCIO Cause of Injury Code
# 1                                       [CHEMICALS]
# 2                       [HOT OBJECTS OR SUBSTANCES]
# 3                            [TEMPERATURE EXTREMES]
# 4                                   [FIRE OR FLAME]
# 5                             [STEAM OR HOT FLUIDS]
# 6                    [DUST, GASES, FUMES OR VAPORS]
# 7                               [WELDING OPERATION]
# 8                                       [RADIATION]
# 9                               [CONTACT WITH, NOC]
# 10                           [MACHINE OR MACHINERY]
# 11                     [COLD OBJECTS OR SUBSTANCES]
# 12                                 [OBJECT HANDLED]
# 13               [CAUGHT IN, UNDER OR BETWEEN, NOC]
# 14                          [ABNORMAL AIR PRESSURE]
# 15                                   [BROKEN GLASS]
# 16                [HAND TOOL, UTENSIL; NOT POWERED]
# 17                 [OBJECT BEING LIFTED OR HANDLED]
# 18                   [POWERED HAND TOOL, APPLIANCE]
# 19                     [CUT, PUNCTURE, SCRAPE, NOC]
# 20         [COLLAPSING MATERIALS (SLIDES OF EARTH)]
# 25               [FROM DIFFERENT LEVEL (ELEVATION)]
# 26                     [FROM LADDER OR SCAFFOLDING]
# 27                   [FROM LIQUID OR GREASE SPILLS]
# 28                                  [INTO OPENINGS]
# 29                                  [ON SAME LEVEL]
# 30                    [SLIP, OR TRIP, DID NOT FALL]
# 31                        [FALL, SLIP OR TRIP, NOC]
# 32                                 [ON ICE OR SNOW]
# 33                                      [ON STAIRS]
# 40                         [CRASH OF WATER VEHICLE]
# 41                          [CRASH OF RAIL VEHICLE]
# 45    [COLLISION OR SIDESWIPE WITH ANOTHER VEHICLE]
# 46                  [COLLISION WITH A FIXED OBJECT]
# 47                              [CRASH OF AIRPLANE]
# 48                                  [VEHICLE UPSET]
# 50                             [MOTOR VEHICLE, NOC]
# 52                                [CONTINUAL NOISE]
# 53                                       [TWISTING]
# 54                             [JUMPING OR LEAPING]
# 55                            [HOLDING OR CARRYING]
# 56                                        [LIFTING]
# 57                             [PUSHING OR PULLING]
# 58                                       [REACHING]
# 59                        [USING TOOL OR MACHINERY]
# 60                       [STRAIN OR INJURY BY, NOC]
# 61                           [WIELDING OR THROWING]
# 65                         [MOVING PART OF MACHINE]
# 66                 [OBJECT BEING LIFTED OR HANDLED]
# 67          [SANDING, SCRAPING, CLEANING OPERATION]
# 68                              [STATIONARY OBJECT]
# 69                       [STEPPING ON SHARP OBJECT]
# 70           [STRIKING AGAINST OR STEPPING ON, NOC]
# 74         [FELLOW WORKER, PATIENT OR OTHER PERSON]
# 75                       [FALLING OR FLYING OBJECT]
# 76                    [HAND TOOL OR MACHINE IN USE]
# 77                                  [MOTOR VEHICLE]
# 78                        [MOVING PARTS OF MACHINE]
# 79                 [OBJECT BEING LIFTED OR HANDLED]
# 80                       [OBJECT HANDLED BY OTHERS]
# 81                         [STRUCK OR INJURED, NOC]
# 82       [ABSORPTION, INGESTION OR INHALATION, NOC]
# 83                                       [PANDEMIC]
# 84                             [ELECTRICAL CURRENT]
# 85                               [ANIMAL OR INSECT]
# 86                        [EXPLOSION OR FLARE BACK]
# 87                [FOREIGN MATTER (BODY) IN EYE(S)]
# 88                              [NATURAL DISASTERS]
# 89                       [PERSON IN ACT OF A CRIME]
# 90            [OTHER THAN PHYSICAL CAUSE OF INJURY]
# 91                                           [MOLD]
# 93                                        [GUNSHOT]
# 94                              [REPETITIVE MOTION]
# 95                         [RUBBED OR ABRADED, NOC]
# 96                                      [TERRORISM]
# 97                              [REPETITIVE MOTION]
# 98                                [CUMULATIVE, NOC]
# 99                     [OTHER - MISCELLANEOUS, NOC]
# Name: WCIO Cause of Injury Description, dtype: object

# %%
group_by_body_part = train_data.groupby("WCIO Part Of Body Code")["WCIO Part Of Body Description"].unique()
group_by_body_part

# different codes with the same description
# Out:
# WCIO Part Of Body Code
# -9                                                 [MULTIPLE]
# 10                                     [MULTIPLE HEAD INJURY]
# 11                                                    [SKULL]
# 12                                                    [BRAIN]
# 13                                                   [EAR(S)]
# 14                                                   [EYE(S)]
# 15                                                     [NOSE]
# 16                                                    [TEETH]
# 17                                                    [MOUTH]
# 18                                              [SOFT TISSUE]
# 19                                             [FACIAL BONES]
# 20                                     [MULTIPLE NECK INJURY]
# 21                                                [VERTEBRAE]
# 22                                                     [DISC]
# 23                                              [SPINAL CORD]
# 24                                                   [LARYNX]
# 25                                              [SOFT TISSUE]
# 26                                                  [TRACHEA]
# 30                               [MULTIPLE UPPER EXTREMITIES]
# 31                                                [UPPER ARM]
# 32                                                    [ELBOW]
# 33                                                [LOWER ARM]
# 34                                                    [WRIST]
# 35                                                     [HAND]
# 36                                                [FINGER(S)]
# 37                                                    [THUMB]
# 38                                              [SHOULDER(S)]
# 39                                      [WRIST (S) & HAND(S)]
# 40                                           [MULTIPLE TRUNK]
# 41                                          [UPPER BACK AREA]
# 42                                          [LOWER BACK AREA]
# 43                                                     [DISC]
# 44                                                    [CHEST]
# 45                                        [SACRUM AND COCCYX]
# 46                                                   [PELVIS]
# 47                                              [SPINAL CORD]
# 48                                          [INTERNAL ORGANS]
# 49                                                    [HEART]
# 50                               [MULTIPLE LOWER EXTREMITIES]
# 51                                                      [HIP]
# 52                                                [UPPER LEG]
# 53                                                     [KNEE]
# 54                                                [LOWER LEG]
# 55                                                    [ANKLE]
# 56                                                     [FOOT]
# 57                                                     [TOES]
# 58                                                [GREAT TOE]
# 60                                                    [LUNGS]
# 61                                  [ABDOMEN INCLUDING GROIN]
# 62                                                 [BUTTOCKS]
# 63                   [LUMBAR & OR SACRAL VERTEBRAE (VERTEBRA]
# 64                                     [ARTIFICIAL APPLIANCE]
# 65    [INSUFFICIENT INFO TO PROPERLY IDENTIFY - UNCLASSIFIED]
# 66                                       [NO PHYSICAL INJURY]
# 90                      [MULTIPLE BODY PARTS (INCLUDING BODY]
# 91                   [BODY SYSTEMS AND MULTIPLE BODY SYSTEMS]
# 99                                               [WHOLE BODY]
# Name: WCIO Part Of Body Description, dtype: object

# %%
# Use describe() to get the descriptive statistics for all variables for train dataset
train_data.describe(include="all").T
# Out:
#                                       count unique  \
# Accident Date                        570337    NaN
# Age at Injury                      574025.0   <NA>
# Alternative Dispute Resolution       574025      3
# Assembly Date                        559466    NaN
# Attorney/Representative              574025      2
# Average Weekly Wage                545374.0    NaN
# Birth Year                         544947.0   <NA>
# C-2 Date                             559466    NaN
# C-3 Date                             187244    NaN
# Carrier Name                         574025   2046
# Carrier Type                         574025      8
# Claim Injury Type                    574025      8
# County of Injury                     574025     63
# COVID-19 Indicator                   574025      2
# District Name                        574025      8
# First Hearing Date                   150797    NaN
# Gender                               574025      4
# IME-4 Count                        132803.0   <NA>
# Industry Code                      564068.0   <NA>
# Industry Code Description            564068     20
# Medical Fee Region                   574025      5
# WCIO Cause of Injury Code          558386.0   <NA>
# WCIO Cause of Injury Description     558386     74
# WCIO Nature of Injury Code         558369.0   <NA>
# WCIO Nature of Injury Description    558369     56
# WCIO Part Of Body Code             556944.0   <NA>
# WCIO Part Of Body Description        556944     54
# Zip Code                             545388   8286
# Agreement Reached                  574025.0    NaN
# WCB Decision                         574025      1
# Number of Dependents               574025.0   <NA>
# Days Between Accident_Assembly       557346    NaN
# Days Between Accident_C2             557346    NaN
# Days Between Accident_C3             183798    NaN
# Days Between Accident_1st_Hearing    149347    NaN
#
#                                                                  top    freq  \
# Accident Date                                                    NaN     NaN
# Age at Injury                                                   <NA>    <NA>
# Alternative Dispute Resolution                                     N  571411
# Assembly Date                                                    NaN     NaN
# Attorney/Representative                                            N  392291
# Average Weekly Wage                                              NaN     NaN
# Birth Year                                                      <NA>    <NA>
# C-2 Date                                                         NaN     NaN
# C-3 Date                                                         NaN     NaN
# Carrier Name                                    STATE INSURANCE FUND  111144
# Carrier Type                                             1A. PRIVATE  285367
# Claim Injury Type                                        2. NON-COMP  291078
# County of Injury                                             SUFFOLK   60430
# COVID-19 Indicator                                                 N  546504
# District Name                                                    NYC  270778
# First Hearing Date                                               NaN     NaN
# Gender                                                             M  335217
# IME-4 Count                                                     <NA>    <NA>
# Industry Code                                                   <NA>    <NA>
# Industry Code Description          HEALTH CARE AND SOCIAL ASSISTANCE  114339
# Medical Fee Region                                                IV  265981
# WCIO Cause of Injury Code                                       <NA>    <NA>
# WCIO Cause of Injury Description                             LIFTING   46610
# WCIO Nature of Injury Code                                      <NA>    <NA>
# WCIO Nature of Injury Description                     STRAIN OR TEAR  153373
# WCIO Part Of Body Code                                          <NA>    <NA>
# WCIO Part Of Body Description                        LOWER BACK AREA   51862
# Zip Code                                                       11236    3398
# Agreement Reached                                                NaN     NaN
# WCB Decision                                        Not Work Related  574025
# Number of Dependents                                            <NA>    <NA>
# Days Between Accident_Assembly                                   NaN     NaN
# Days Between Accident_C2                                         NaN     NaN
# Days Between Accident_C3                                         NaN     NaN
# Days Between Accident_1st_Hearing                                NaN     NaN
#
#                                                             mean  \
# Accident Date                      2021-04-28 21:00:27.892982784
# Age at Injury                                          42.114343
# Alternative Dispute Resolution                               NaN
# Assembly Date                      2021-07-16 20:11:19.865443328
# Attorney/Representative                                      NaN
# Average Weekly Wage                                   491.089221
# Birth Year                                            137.232546
# C-2 Date                           2021-07-16 20:11:19.865443328
# C-3 Date                           2021-07-26 21:32:29.772489728
# Carrier Name                                                 NaN
# Carrier Type                                                 NaN
# Claim Injury Type                                            NaN
# County of Injury                                             NaN
# COVID-19 Indicator                                           NaN
# District Name                                                NaN
# First Hearing Date                 2022-03-19 05:05:32.863386368
# Gender                                                       NaN
# IME-4 Count                                             3.207337
# Industry Code                                          58.645305
# Industry Code Description                                    NaN
# Medical Fee Region                                           NaN
# WCIO Cause of Injury Code                              54.381143
# WCIO Cause of Injury Description                             NaN
# WCIO Nature of Injury Code                             41.013839
# WCIO Nature of Injury Description                            NaN
# WCIO Part Of Body Code                                 39.738146
# WCIO Part Of Body Description                                NaN
# Zip Code                                                     NaN
# Agreement Reached                                       0.046665
# WCB Decision                                                 NaN
# Number of Dependents                                    3.006564
# Days Between Accident_Assembly        70 days 08:26:12.216899374
# Days Between Accident_C2              70 days 08:26:12.216899374
# Days Between Accident_C3              97 days 10:39:47.307805308
# Days Between Accident_1st_Hearing    335 days 01:58:03.380315640
#
#                                                     min                  25%  \
# Accident Date                       1961-09-06 00:00:00  2020-09-14 00:00:00
# Age at Injury                                       0.0                 31.0
# Alternative Dispute Resolution                      NaN                  NaN
# Assembly Date                       1996-01-12 00:00:00  2020-11-06 00:00:00
# Attorney/Representative                             NaN                  NaN
# Average Weekly Wage                                 0.0                  0.0
# Birth Year                                          6.0                 35.0
# C-2 Date                            1996-01-12 00:00:00  2020-11-06 00:00:00
# C-3 Date                            1992-11-13 00:00:00  2020-10-27 00:00:00
# Carrier Name                                        NaN                  NaN
# Carrier Type                                        NaN                  NaN
# Claim Injury Type                                   NaN                  NaN
# County of Injury                                    NaN                  NaN
# COVID-19 Indicator                                  NaN                  NaN
# District Name                                       NaN                  NaN
# First Hearing Date                  2020-01-30 00:00:00  2021-06-01 00:00:00
# Gender                                              NaN                  NaN
# IME-4 Count                                         1.0                  1.0
# Industry Code                                      11.0                 45.0
# Industry Code Description                           NaN                  NaN
# Medical Fee Region                                  NaN                  NaN
# WCIO Cause of Injury Code                           1.0                 31.0
# WCIO Cause of Injury Description                    NaN                  NaN
# WCIO Nature of Injury Code                          1.0                 16.0
# WCIO Nature of Injury Description                   NaN                  NaN
# WCIO Part Of Body Code                             -9.0                 33.0
# WCIO Part Of Body Description                       NaN                  NaN
# Zip Code                                            NaN                  NaN
# Agreement Reached                                   0.0                  0.0
# WCB Decision                                        NaN                  NaN
# Number of Dependents                                0.0                  1.0
# Days Between Accident_Assembly     -8842 days +00:00:00      5 days 00:00:00
# Days Between Accident_C2           -8842 days +00:00:00      5 days 00:00:00
# Days Between Accident_C3           -9870 days +00:00:00     12 days 00:00:00
# Days Between Accident_1st_Hearing   -576 days +00:00:00    147 days 00:00:00
#
#                                                    50%                  75%  \
# Accident Date                      2021-06-27 00:00:00  2022-03-21 00:00:00
# Age at Injury                                     42.0                 54.0
# Alternative Dispute Resolution                     NaN                  NaN
# Assembly Date                      2021-08-09 00:00:00  2022-04-26 00:00:00
# Attorney/Representative                            NaN                  NaN
# Average Weekly Wage                                0.0                841.0
# Birth Year                                        47.0                 59.0
# C-2 Date                           2021-08-09 00:00:00  2022-04-26 00:00:00
# C-3 Date                           2021-07-21 00:00:00  2022-04-20 00:00:00
# Carrier Name                                       NaN                  NaN
# Carrier Type                                       NaN                  NaN
# Claim Injury Type                                  NaN                  NaN
# County of Injury                                   NaN                  NaN
# COVID-19 Indicator                                 NaN                  NaN
# District Name                                      NaN                  NaN
# First Hearing Date                 2022-03-09 00:00:00  2023-01-11 00:00:00
# Gender                                             NaN                  NaN
# IME-4 Count                                        2.0                  4.0
# Industry Code                                     61.0                 71.0
# Industry Code Description                          NaN                  NaN
# Medical Fee Region                                 NaN                  NaN
# WCIO Cause of Injury Code                         56.0                 75.0
# WCIO Cause of Injury Description                   NaN                  NaN
# WCIO Nature of Injury Code                        49.0                 52.0
# WCIO Nature of Injury Description                  NaN                  NaN
# WCIO Part Of Body Code                            38.0                 53.0
# WCIO Part Of Body Description                      NaN                  NaN
# Zip Code                                           NaN                  NaN
# Agreement Reached                                  0.0                  0.0
# WCB Decision                                       NaN                  NaN
# Number of Dependents                               3.0                  5.0
# Days Between Accident_Assembly        10 days 00:00:00     27 days 00:00:00
# Days Between Accident_C2              10 days 00:00:00     27 days 00:00:00
# Days Between Accident_C3              27 days 00:00:00     71 days 00:00:00
# Days Between Accident_1st_Hearing    237 days 00:00:00    420 days 00:00:00
#
#                                                    max  \
# Accident Date                      2023-09-29 00:00:00
# Age at Injury                                    117.0
# Alternative Dispute Resolution                     NaN
# Assembly Date                      2024-06-01 00:00:00
# Attorney/Representative                            NaN
# Average Weekly Wage                          2828079.0
# Birth Year                                      2024.0
# C-2 Date                           2024-06-01 00:00:00
# C-3 Date                           2024-05-31 00:00:00
# Carrier Name                                       NaN
# Carrier Type                                       NaN
# Claim Injury Type                                  NaN
# County of Injury                                   NaN
# COVID-19 Indicator                                 NaN
# District Name                                      NaN
# First Hearing Date                 2024-06-07 00:00:00
# Gender                                             NaN
# IME-4 Count                                       73.0
# Industry Code                                     92.0
# Industry Code Description                          NaN
# Medical Fee Region                                 NaN
# WCIO Cause of Injury Code                         99.0
# WCIO Cause of Injury Description                   NaN
# WCIO Nature of Injury Code                        91.0
# WCIO Nature of Injury Description                  NaN
# WCIO Part Of Body Code                            99.0
# WCIO Part Of Body Description                      NaN
# Zip Code                                           NaN
# Agreement Reached                                  1.0
# WCB Decision                                       NaN
# Number of Dependents                               6.0
# Days Between Accident_Assembly     21503 days 00:00:00
# Days Between Accident_C2           21503 days 00:00:00
# Days Between Accident_C3           18566 days 00:00:00
# Days Between Accident_1st_Hearing  16373 days 00:00:00
#
#                                                            std
# Accident Date                                              NaN
# Age at Injury                                        14.256336
# Alternative Dispute Resolution                             NaN
# Assembly Date                                              NaN
# Attorney/Representative                                    NaN
# Average Weekly Wage                                 6092.92367
# Birth Year                                          414.644789
# C-2 Date                                                   NaN
# C-3 Date                                                   NaN
# Carrier Name                                               NaN
# Carrier Type                                               NaN
# Claim Injury Type                                          NaN
# County of Injury                                           NaN
# COVID-19 Indicator                                         NaN
# District Name                                              NaN
# First Hearing Date                                         NaN
# Gender                                                     NaN
# IME-4 Count                                           2.832303
# Industry Code                                        19.644175
# Industry Code Description                                  NaN
# Medical Fee Region                                         NaN
# WCIO Cause of Injury Code                            25.874281
# WCIO Cause of Injury Description                           NaN
# WCIO Nature of Injury Code                           22.207521
# WCIO Nature of Injury Description                          NaN
# WCIO Part Of Body Code                                22.36594
# WCIO Part Of Body Description                              NaN
# Zip Code                                                   NaN
# Agreement Reached                                     0.210921
# WCB Decision                                               NaN
# Number of Dependents                                  2.000799
# Days Between Accident_Assembly     511 days 15:12:29.067530256
# Days Between Accident_C2           511 days 15:12:29.067530256
# Days Between Accident_C3           406 days 02:19:27.364693768
# Days Between Accident_1st_Hearing  438 days 11:15:57.770328568

# %% [markdown]
# #### STRANGE VALUES:

# %%
# Check for strange characters by NaN on train dataset:
# Strange values indicative of missing values: 
# Alternative dispute resolution (percentage)
# Birth year (0) (No issues) 
# Carrier type: 'UNKNOWN'()/ 5D. SPECIAL FUND - UNKNOWN (percentage)
# Claim injury type (cancelled ??) ------------------
# County of injury (unknown) (percentage)
# Gender ("U") (percentage)
# Medical Fee region (UK??) (percentage) 
# WCIO Part Of Body Description ("Insufficient info to properly classify") (percentage)--------------
# Zip code == 0000 (??)
# Weekly wage (0) 75% of values

# %% [markdown]
# #### - Check percentage of strange values in the dataset:

# %%
# % of UK values in medical fee region - it's significant (can't remove it)
medical_fee_count = (train_data['Medical Fee Region'] == 'UK').sum()
total_count = len(train_data)
percentage_medical_fee = (medical_fee_count / total_count) * 100
percentage_medical_fee.round(4)
# Out:
# 5.8311

# %%
# % of U values in alternative dispute resolution - U Gender is significant. X gender, significant??
gender_count = (train_data['Gender'] == 'U').sum()
total_count = len(train_data)  
percentage_gender_U = (gender_count / total_count) * 100
print(f"Gender U: {percentage_gender_U.round(4)}%")

gender_count = (train_data['Gender'] == 'X').sum()
total_count = len(train_data)
percentage_gender_X = (gender_count / total_count) * 100
print(f"Gender X: {percentage_gender_X.round(4)}%")
# Out:
# Gender U: 0.8207%
# Gender X: 0.008%

# %%
# % of "Insufficient info to properly classify" in WCIO Part Of Body Description - It's significant!
gender_count = (train_data['WCIO Part Of Body Description'] == 'INSUFFICIENT INFO TO PROPERLY IDENTIFY - UNCLASSIFIED').sum()
total_count = len(train_data)
percentage_gender_X = (gender_count / total_count) * 100
percentage_gender_X.round(4)
# Out:
# 0.9252

# %%
# % of U values in alternative dispute resolution - significant??
alternative_dispute_resolution_count = (train_data['Alternative Dispute Resolution'] == 'U').sum()  
total_count = len(train_data)  
percentage_alternative_dispute_resolution = (alternative_dispute_resolution_count / total_count) * 100
percentage_alternative_dispute_resolution
# Out:
# 0.0008710422019946866

# %%
# % of unknown values in county of injury - significant?? 
county_injury_count = (train_data['County of Injury'] == 'UNKNOWN').sum()
total_count = len(train_data)  
percentage_county_injury = (county_injury_count / total_count) * 100
percentage_county_injury
# Out:
# 0.20835329471712905

# %% [markdown]
# #### Define target variable

# %%
x = train_data.drop('Claim Injury Type', axis = 1) # axis=1 means the operation must be done on columns
y = train_data['Claim Injury Type']

# %% [markdown]
# ### Define metric & non-metric features

# %%
metric_features = ["Age at Injury", "Average Weekly Wage", "Birth Year", "IME-4 Count", "Number_of_Dependents", "Days Between Accident_Assembly", "Days Between Accident_C2", 
                   "Days Between Accident_C3", "Days Between Accident_1st_Hearing"]

non_metric_features = ["Industry Code", "WCIO Cause of Injury Code", "WCIO Nature of Injury Code", "WCIO Part Of Body Code", "Accident Date", "Alternative Dispute Resolution",
                       "Assembly Date", "Attorney/Representative", "C-2 Date", "C-3 Date", "Carrier Name", "Carrier Type", "County of Injury", "COVID-19 Indicator",
                       "District Name", "First Hearing Date", "Gender", "Industry Code Description", "Medical Fee Region", "WCIO Cause of Injury Description", 
                       "WCIO Nature of Injury Description", "WCIO Part Of Body Description", "Zip Code", "Agreement Reached", "WCB Decision"]

# %%
# handling missing values in the dataset
